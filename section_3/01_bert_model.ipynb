# %% [markdown]
# <a href="https://colab.research.google.com/github/moseskim/bert_nlp/blob/main/section_3/01_bert_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BERT 모델
#
# 자연 언어 처리 라이브러리인 PyTorch-Transformers를 사용한 BERT 모델 구현을 살펴봅니다.

# %% [markdown]
# ## 라이브러리 설치
#
# PyTorch-Transformers, 및 필요한 라이브러리를 설치합니다.

# %%
# !pip install folium==0.2.1
# !pip install urllib3==1.25.11
# !pip install pytorch-transformers==1.2.0

# %% [markdown]
# ## BERT 모델
#
# PyTorch-Transformers에서는 다양한 훈련 완료 모델을 다루는 클래스를 제공합니다.
# 이번에는 가장 기본적인 모델인 `BertModel`의 내용을 확인합니다.

# %%
import torch
from pytorch_transformers import BertModel

bert_model = BertModel.from_pretrained('bert-base-uncased')  # 훈련 완료 매개변수 로딩
print(bert_model)

# %% [markdown]
# # BERT 설정
#
# `BertConfig` 클래스를 사용해 모델 설정을 확인합니다.

# %%
from pytorch_transformers import BertConfig

config = BertConfig.from_pretrained("bert-base-uncased")
print(config)
